# %% [markdown]
# # Clean dropbox
#
# We have a lot of tests and sometimes simply forget to clean the dropbox. This is a simple code to clean the dropbox.

# %%
import sys

import dropbox
from dropbox.exceptions import AuthError
from decouple import config

# %%
app_key = config("APP_KEY")
app_secret = config("APP_SECRET")
refresh_token = config("REFRESH_TOKEN")

# %% [markdown]
# clean the configs

# %%
def clean_dummies_from_folder(folder_path:str):
    folder_path = folder_path.strip("/")

    folder_path = "/" + folder_path + "/"
    with dropbox.Dropbox(
        app_key=app_key,
        app_secret=app_secret,
        oauth2_refresh_token=refresh_token,
    ) as dbx:
        # Check that the access token is valid
        try:
            dbx.users_get_current_account()
        except AuthError:
            sys.exit("ERROR: Invalid access token.")

        folders_results = dbx.files_list_folder(path=folder_path)
        entries = folders_results.entries
        for entry in entries:
            if "dummy" in entry.name:
                print("Deleting folder: " + entry.name)
                full_path = folder_path + entry.name

                print("Deleting folder: " + full_path)
                _ = dbx.files_delete_v2(path=full_path)

# %%
backend_config_path = "/Backend_files/Config/"
clean_dummies_from_folder(backend_config_path)

# %% [markdown]
# Clean the finished jobs

# %%
folder_path = "/Backend_files/Finished_Jobs/"
clean_dummies_from_folder(folder_path)
# Out:
# Deleting folder: dummy030ba
# Deleting folder: /Backend_files/Finished_Jobs/dummy030ba
# Deleting folder: dummy80bb8
# Deleting folder: /Backend_files/Finished_Jobs/dummy80bb8
# Deleting folder: dummyead3c
# Deleting folder: /Backend_files/Finished_Jobs/dummyead3c
# Deleting folder: dummybe762
# Deleting folder: /Backend_files/Finished_Jobs/dummybe762
# Deleting folder: dummydd201
# Deleting folder: /Backend_files/Finished_Jobs/dummydd201
# Deleting folder: dummya1490
# Deleting folder: /Backend_files/Finished_Jobs/dummya1490
# Deleting folder: dummyc0920
# Deleting folder: /Backend_files/Finished_Jobs/dummyc0920
# Deleting folder: dummy87930
# Deleting folder: /Backend_files/Finished_Jobs/dummy87930
# Deleting folder: dummy9b60a
# Deleting folder: /Backend_files/Finished_Jobs/dummy9b60a
# Deleting folder: dummy5c519
# Deleting folder: /Backend_files/Finished_Jobs/dummy5c519
# Deleting folder: dummye939d
# Deleting folder: /Backend_files/Finished_Jobs/dummye939d
# Deleting folder: dummycb627
# Deleting folder: /Backend_files/Finished_Jobs/dummycb627
# Deleting folder: dummyfc541
# Deleting folder: /Backend_files/Finished_Jobs/dummyfc541
# Deleting folder: dummya9e64
# Deleting folder: /Backend_files/Finished_Jobs/dummya9e64
# Deleting folder: dummy009eb
# Deleting folder: /Backend_files/Finished_Jobs/dummy009eb
# Deleting folder: dummydedd0
# Deleting folder: /Backend_files/Finished_Jobs/dummydedd0
# Deleting folder: dummyd18a5
# Deleting folder: /Backend_files/Finished_Jobs/dummyd18a5
# Deleting folder: dummye9071
# Deleting folder: /Backend_files/Finished_Jobs/dummye9071
# Deleting folder: dummy2dd70
# Deleting folder: /Backend_files/Finished_Jobs/dummy2dd70
# Deleting folder: dummy2c9ca
# Deleting folder: /Backend_files/Finished_Jobs/dummy2c9ca
# Deleting folder: dummyb621e
# Deleting folder: /Backend_files/Finished_Jobs/dummyb621e
# Deleting folder: dummy62192
# Deleting folder: /Backend_files/Finished_Jobs/dummy62192
# Deleting folder: dummy24736
# Deleting folder: /Backend_files/Finished_Jobs/dummy24736
# Deleting folder: dummy8f939
# Deleting folder: /Backend_files/Finished_Jobs/dummy8f939
# Deleting folder: dummyc0072
# Deleting folder: /Backend_files/Finished_Jobs/dummyc0072
# Deleting folder: dummy399be
# Deleting folder: /Backend_files/Finished_Jobs/dummy399be
# Deleting folder: dummy663cd
# Deleting folder: /Backend_files/Finished_Jobs/dummy663cd
# Deleting folder: dummy1cb47
# Deleting folder: /Backend_files/Finished_Jobs/dummy1cb47
# Deleting folder: dummybdcb4
# Deleting folder: /Backend_files/Finished_Jobs/dummybdcb4
# Deleting folder: dummyef440
# Deleting folder: /Backend_files/Finished_Jobs/dummyef440
# Deleting folder: dummyba932
# Deleting folder: /Backend_files/Finished_Jobs/dummyba932
# Deleting folder: dummy9632e
# Deleting folder: /Backend_files/Finished_Jobs/dummy9632e
# Deleting folder: dummy4da0f
# Deleting folder: /Backend_files/Finished_Jobs/dummy4da0f
# Deleting folder: dummyadf3c
# Deleting folder: /Backend_files/Finished_Jobs/dummyadf3c
# Deleting folder: dummy4add5
# Deleting folder: /Backend_files/Finished_Jobs/dummy4add5
# Deleting folder: dummye534c
# Deleting folder: /Backend_files/Finished_Jobs/dummye534c
# Deleting folder: dummy33f2b
# Deleting folder: /Backend_files/Finished_Jobs/dummy33f2b
# Deleting folder: dummy8862e
# Deleting folder: /Backend_files/Finished_Jobs/dummy8862e
# Deleting folder: dummy33239
# Deleting folder: /Backend_files/Finished_Jobs/dummy33239
# Deleting folder: dummye43e5
# Deleting folder: /Backend_files/Finished_Jobs/dummye43e5
# Deleting folder: dummybc8af
# Deleting folder: /Backend_files/Finished_Jobs/dummybc8af
# Deleting folder: dummy2be62
# Deleting folder: /Backend_files/Finished_Jobs/dummy2be62
# Deleting folder: dummy2a019
# Deleting folder: /Backend_files/Finished_Jobs/dummy2a019
# Deleting folder: dummy11209
# Deleting folder: /Backend_files/Finished_Jobs/dummy11209
# Deleting folder: dummyd7a02
# Deleting folder: /Backend_files/Finished_Jobs/dummyd7a02
# Deleting folder: dummy2290c
# Deleting folder: /Backend_files/Finished_Jobs/dummy2290c
# Deleting folder: dummyb9bab
# Deleting folder: /Backend_files/Finished_Jobs/dummyb9bab
# Deleting folder: dummy61f9a
# Deleting folder: /Backend_files/Finished_Jobs/dummy61f9a
# Deleting folder: dummydc0a4
# Deleting folder: /Backend_files/Finished_Jobs/dummydc0a4
# Deleting folder: dummyace8d
# Deleting folder: /Backend_files/Finished_Jobs/dummyace8d
# Deleting folder: dummye01f8
# Deleting folder: /Backend_files/Finished_Jobs/dummye01f8
# Deleting folder: dummyddbbb
# Deleting folder: /Backend_files/Finished_Jobs/dummyddbbb
# Deleting folder: dummy6a53e
# Deleting folder: /Backend_files/Finished_Jobs/dummy6a53e
# Deleting folder: dummy6e816
# Deleting folder: /Backend_files/Finished_Jobs/dummy6e816
# Deleting folder: dummy30a13
# Deleting folder: /Backend_files/Finished_Jobs/dummy30a13
# Deleting folder: dummye34f6
# Deleting folder: /Backend_files/Finished_Jobs/dummye34f6
# Deleting folder: dummy12fdc
# Deleting folder: /Backend_files/Finished_Jobs/dummy12fdc
# Deleting folder: dummy08029
# Deleting folder: /Backend_files/Finished_Jobs/dummy08029
# Deleting folder: dummy34837
# Deleting folder: /Backend_files/Finished_Jobs/dummy34837
# Deleting folder: dummy6f00a
# Deleting folder: /Backend_files/Finished_Jobs/dummy6f00a
# Deleting folder: dummyc6116
# Deleting folder: /Backend_files/Finished_Jobs/dummyc6116
# Deleting folder: dummye3ea1
# Deleting folder: /Backend_files/Finished_Jobs/dummye3ea1
# Deleting folder: dummy97785
# Deleting folder: /Backend_files/Finished_Jobs/dummy97785
# Deleting folder: dummy3f099
# Deleting folder: /Backend_files/Finished_Jobs/dummy3f099
# Deleting folder: dummy5f4cf
# Deleting folder: /Backend_files/Finished_Jobs/dummy5f4cf
# Deleting folder: dummy04689
# Deleting folder: /Backend_files/Finished_Jobs/dummy04689
# Deleting folder: dummy660fe
# Deleting folder: /Backend_files/Finished_Jobs/dummy660fe
# Deleting folder: dummy1f0bd
# Deleting folder: /Backend_files/Finished_Jobs/dummy1f0bd
# Deleting folder: dummy922cd
# Deleting folder: /Backend_files/Finished_Jobs/dummy922cd
# Deleting folder: dummyadea3
# Deleting folder: /Backend_files/Finished_Jobs/dummyadea3
# Deleting folder: dummy88e4f
# Deleting folder: /Backend_files/Finished_Jobs/dummy88e4f
# Deleting folder: dummybbfaa
# Deleting folder: /Backend_files/Finished_Jobs/dummybbfaa
# Deleting folder: dummy320db
# Deleting folder: /Backend_files/Finished_Jobs/dummy320db
# Deleting folder: dummyd0f09
# Deleting folder: /Backend_files/Finished_Jobs/dummyd0f09
# Deleting folder: dummy365c5
# Deleting folder: /Backend_files/Finished_Jobs/dummy365c5
# Deleting folder: dummyf5f52
# Deleting folder: /Backend_files/Finished_Jobs/dummyf5f52
# Deleting folder: dummyf2671
# Deleting folder: /Backend_files/Finished_Jobs/dummyf2671
# Deleting folder: dummycda4a
# Deleting folder: /Backend_files/Finished_Jobs/dummycda4a
# Deleting folder: dummy6e297
# Deleting folder: /Backend_files/Finished_Jobs/dummy6e297
# Deleting folder: dummy0a9b3
# Deleting folder: /Backend_files/Finished_Jobs/dummy0a9b3
# Deleting folder: dummyee107
# Deleting folder: /Backend_files/Finished_Jobs/dummyee107
# Deleting folder: dummy66a47
# Deleting folder: /Backend_files/Finished_Jobs/dummy66a47
# Deleting folder: dummyf08cb
# Deleting folder: /Backend_files/Finished_Jobs/dummyf08cb
# Deleting folder: dummy6bc75
# Deleting folder: /Backend_files/Finished_Jobs/dummy6bc75
# Deleting folder: dummy01bb5
# Deleting folder: /Backend_files/Finished_Jobs/dummy01bb5
# Deleting folder: dummy7ee86
# Deleting folder: /Backend_files/Finished_Jobs/dummy7ee86
# Deleting folder: dummybb37f
# Deleting folder: /Backend_files/Finished_Jobs/dummybb37f
# Deleting folder: dummy7e925
# Deleting folder: /Backend_files/Finished_Jobs/dummy7e925
# Deleting folder: dummy02fb9
# Deleting folder: /Backend_files/Finished_Jobs/dummy02fb9
# Deleting folder: dummya1d72
# Deleting folder: /Backend_files/Finished_Jobs/dummya1d72
# Deleting folder: dummy50764
# Deleting folder: /Backend_files/Finished_Jobs/dummy50764
# Deleting folder: dummy64a0b
# Deleting folder: /Backend_files/Finished_Jobs/dummy64a0b
# Deleting folder: dummy2c262
# Deleting folder: /Backend_files/Finished_Jobs/dummy2c262
# Deleting folder: dummy8ec3e
# Deleting folder: /Backend_files/Finished_Jobs/dummy8ec3e
# Deleting folder: dummy5c5c3
# Deleting folder: /Backend_files/Finished_Jobs/dummy5c5c3
# Deleting folder: dummyc4866
# Deleting folder: /Backend_files/Finished_Jobs/dummyc4866
# Deleting folder: dummyf1e56
# Deleting folder: /Backend_files/Finished_Jobs/dummyf1e56
# Deleting folder: dummy12d14
# Deleting folder: /Backend_files/Finished_Jobs/dummy12d14
# Deleting folder: dummy1e9c0
# Deleting folder: /Backend_files/Finished_Jobs/dummy1e9c0
# Deleting folder: dummy8b62e
# Deleting folder: /Backend_files/Finished_Jobs/dummy8b62e
# Deleting folder: dummy09800
# Deleting folder: /Backend_files/Finished_Jobs/dummy09800
# Deleting folder: dummy229b6
# Deleting folder: /Backend_files/Finished_Jobs/dummy229b6
# Deleting folder: dummyd7be8
# Deleting folder: /Backend_files/Finished_Jobs/dummyd7be8
# Deleting folder: dummy958c1
# Deleting folder: /Backend_files/Finished_Jobs/dummy958c1
# Deleting folder: dummye9153
# Deleting folder: /Backend_files/Finished_Jobs/dummye9153
# Deleting folder: dummy4386c
# Deleting folder: /Backend_files/Finished_Jobs/dummy4386c
# Deleting folder: dummy643fd
# Deleting folder: /Backend_files/Finished_Jobs/dummy643fd
# Deleting folder: dummyf1f2d
# Deleting folder: /Backend_files/Finished_Jobs/dummyf1f2d
# Deleting folder: dummy300d9
# Deleting folder: /Backend_files/Finished_Jobs/dummy300d9
# Deleting folder: dummybe164
# Deleting folder: /Backend_files/Finished_Jobs/dummybe164
# Deleting folder: dummyeea12
# Deleting folder: /Backend_files/Finished_Jobs/dummyeea12
# Deleting folder: dummy061f8
# Deleting folder: /Backend_files/Finished_Jobs/dummy061f8
# Deleting folder: dummyad229
# Deleting folder: /Backend_files/Finished_Jobs/dummyad229
# Deleting folder: dummy701df
# Deleting folder: /Backend_files/Finished_Jobs/dummy701df
# Deleting folder: dummy21ef4
# Deleting folder: /Backend_files/Finished_Jobs/dummy21ef4
# Deleting folder: dummybfa4f
# Deleting folder: /Backend_files/Finished_Jobs/dummybfa4f
# Deleting folder: dummyf83b3
# Deleting folder: /Backend_files/Finished_Jobs/dummyf83b3
# Deleting folder: dummy16632
# Deleting folder: /Backend_files/Finished_Jobs/dummy16632
# Deleting folder: dummy3da9e
# Deleting folder: /Backend_files/Finished_Jobs/dummy3da9e
# Deleting folder: dummy45daa
# Deleting folder: /Backend_files/Finished_Jobs/dummy45daa
# Deleting folder: dummy23814
# Deleting folder: /Backend_files/Finished_Jobs/dummy23814
# Deleting folder: dummy02966
# Deleting folder: /Backend_files/Finished_Jobs/dummy02966
# Deleting folder: dummy945b7
# Deleting folder: /Backend_files/Finished_Jobs/dummy945b7
# Deleting folder: dummy28ddd
# Deleting folder: /Backend_files/Finished_Jobs/dummy28ddd
# Deleting folder: dummye6280
# Deleting folder: /Backend_files/Finished_Jobs/dummye6280
# Deleting folder: dummye40e1
# Deleting folder: /Backend_files/Finished_Jobs/dummye40e1
# Deleting folder: dummy3e9de
# Deleting folder: /Backend_files/Finished_Jobs/dummy3e9de
# Deleting folder: dummy0a55d
# Deleting folder: /Backend_files/Finished_Jobs/dummy0a55d
# Deleting folder: dummyb55e4
# Deleting folder: /Backend_files/Finished_Jobs/dummyb55e4
# Deleting folder: dummy12be1
# Deleting folder: /Backend_files/Finished_Jobs/dummy12be1
# Deleting folder: dummyf470d
# Deleting folder: /Backend_files/Finished_Jobs/dummyf470d
# Deleting folder: dummyce9e9
# Deleting folder: /Backend_files/Finished_Jobs/dummyce9e9
# Deleting folder: dummy6cd72
# Deleting folder: /Backend_files/Finished_Jobs/dummy6cd72
# Deleting folder: dummyb87e5
# Deleting folder: /Backend_files/Finished_Jobs/dummyb87e5
# Deleting folder: dummy270a6
# Deleting folder: /Backend_files/Finished_Jobs/dummy270a6
# Deleting folder: dummy3a8c6
# Deleting folder: /Backend_files/Finished_Jobs/dummy3a8c6
# Deleting folder: dummyb6983
# Deleting folder: /Backend_files/Finished_Jobs/dummyb6983
# Deleting folder: dummydbe3f
# Deleting folder: /Backend_files/Finished_Jobs/dummydbe3f
# Deleting folder: dummy1149a
# Deleting folder: /Backend_files/Finished_Jobs/dummy1149a

# %%
folder_path = "/Backend_files/Queued_Jobs/"
clean_dummies_from_folder(folder_path)
# Out:
# Deleting folder: dummy3da9e
# Deleting folder: /Backend_files/Queued_Jobs/dummy3da9e
# Deleting folder: dummy3789c
# Deleting folder: /Backend_files/Queued_Jobs/dummy3789c
# Deleting folder: dummy45daa
# Deleting folder: /Backend_files/Queued_Jobs/dummy45daa
# Deleting folder: dummyacb10
# Deleting folder: /Backend_files/Queued_Jobs/dummyacb10
# Deleting folder: dummy23814
# Deleting folder: /Backend_files/Queued_Jobs/dummy23814
# Deleting folder: dummy1b516
# Deleting folder: /Backend_files/Queued_Jobs/dummy1b516
# Deleting folder: dummy02966
# Deleting folder: /Backend_files/Queued_Jobs/dummy02966
# Deleting folder: dummy485d9
# Deleting folder: /Backend_files/Queued_Jobs/dummy485d9
# Deleting folder: dummy945b7
# Deleting folder: /Backend_files/Queued_Jobs/dummy945b7
# Deleting folder: dummy1939c
# Deleting folder: /Backend_files/Queued_Jobs/dummy1939c
# Deleting folder: dummy28ddd
# Deleting folder: /Backend_files/Queued_Jobs/dummy28ddd
# Deleting folder: dummy2bcf6
# Deleting folder: /Backend_files/Queued_Jobs/dummy2bcf6
# Deleting folder: dummye6280
# Deleting folder: /Backend_files/Queued_Jobs/dummye6280
# Deleting folder: dummy4376e
# Deleting folder: /Backend_files/Queued_Jobs/dummy4376e
# Deleting folder: dummye40e1
# Deleting folder: /Backend_files/Queued_Jobs/dummye40e1
# Deleting folder: dummyc6cea
# Deleting folder: /Backend_files/Queued_Jobs/dummyc6cea
# Deleting folder: dummy3e9de
# Deleting folder: /Backend_files/Queued_Jobs/dummy3e9de
# Deleting folder: dummyb2461
# Deleting folder: /Backend_files/Queued_Jobs/dummyb2461
# Deleting folder: dummy0a55d
# Deleting folder: /Backend_files/Queued_Jobs/dummy0a55d
# Deleting folder: dummybc75c
# Deleting folder: /Backend_files/Queued_Jobs/dummybc75c
# Deleting folder: dummyb55e4
# Deleting folder: /Backend_files/Queued_Jobs/dummyb55e4
# Deleting folder: dummy73366
# Deleting folder: /Backend_files/Queued_Jobs/dummy73366
# Deleting folder: dummy12be1
# Deleting folder: /Backend_files/Queued_Jobs/dummy12be1
# Deleting folder: dummyd3265
# Deleting folder: /Backend_files/Queued_Jobs/dummyd3265
# Deleting folder: dummy6e63b
# Deleting folder: /Backend_files/Queued_Jobs/dummy6e63b
# Deleting folder: dummy94e7d
# Deleting folder: /Backend_files/Queued_Jobs/dummy94e7d
# Deleting folder: dummyf470d
# Deleting folder: /Backend_files/Queued_Jobs/dummyf470d
# Deleting folder: dummy52444
# Deleting folder: /Backend_files/Queued_Jobs/dummy52444
# Deleting folder: dummyce9e9
# Deleting folder: /Backend_files/Queued_Jobs/dummyce9e9
# Deleting folder: dummyafb38
# Deleting folder: /Backend_files/Queued_Jobs/dummyafb38
# Deleting folder: dummy6cd72
# Deleting folder: /Backend_files/Queued_Jobs/dummy6cd72
# Deleting folder: dummy510d9
# Deleting folder: /Backend_files/Queued_Jobs/dummy510d9
# Deleting folder: dummyb87e5
# Deleting folder: /Backend_files/Queued_Jobs/dummyb87e5
# Deleting folder: dummyc4857
# Deleting folder: /Backend_files/Queued_Jobs/dummyc4857
# Deleting folder: dummy270a6
# Deleting folder: /Backend_files/Queued_Jobs/dummy270a6
# Deleting folder: dummy10787
# Deleting folder: /Backend_files/Queued_Jobs/dummy10787
# Deleting folder: dummy3a8c6
# Deleting folder: /Backend_files/Queued_Jobs/dummy3a8c6
# Deleting folder: dummyb6efa
# Deleting folder: /Backend_files/Queued_Jobs/dummyb6efa
# Deleting folder: dummyb6983
# Deleting folder: /Backend_files/Queued_Jobs/dummyb6983
# Deleting folder: dummy86137
# Deleting folder: /Backend_files/Queued_Jobs/dummy86137
# Deleting folder: dummydbe3f
# Deleting folder: /Backend_files/Queued_Jobs/dummydbe3f
# Deleting folder: dummy86ddf
# Deleting folder: /Backend_files/Queued_Jobs/dummy86ddf
# Deleting folder: dummy1149a
# Deleting folder: /Backend_files/Queued_Jobs/dummy1149a
# Deleting folder: dummyc079f
# Deleting folder: /Backend_files/Queued_Jobs/dummyc079f
# Deleting folder: dummy7566f
# Deleting folder: /Backend_files/Queued_Jobs/dummy7566f
# Deleting folder: dummy71da9
# Deleting folder: /Backend_files/Queued_Jobs/dummy71da9
# Deleting folder: dummy07593
# Deleting folder: /Backend_files/Queued_Jobs/dummy07593

# %%
folder_path = "/Backend_files/Result/"
clean_dummies_from_folder(folder_path)
# Out:
# Deleting folder: dummy1149a
# Deleting folder: /Backend_files/Result/dummy1149a
# Deleting folder: dummyc079f
# Deleting folder: /Backend_files/Result/dummyc079f
# Deleting folder: dummy7566f
# Deleting folder: /Backend_files/Result/dummy7566f
# Deleting folder: dummy71da9
# Deleting folder: /Backend_files/Result/dummy71da9
# Deleting folder: dummy07593
# Deleting folder: /Backend_files/Result/dummy07593

# %%
folder_path = "/Backend_files/Status/"
clean_dummies_from_folder(folder_path)
# Out:
# Deleting folder: dummyb6efa
# Deleting folder: /Backend_files/Status/dummyb6efa
# Deleting folder: dummyb6983
# Deleting folder: /Backend_files/Status/dummyb6983
# Deleting folder: dummy86137
# Deleting folder: /Backend_files/Status/dummy86137
# Deleting folder: dummydbe3f
# Deleting folder: /Backend_files/Status/dummydbe3f
# Deleting folder: dummy86ddf
# Deleting folder: /Backend_files/Status/dummy86ddf
# Deleting folder: dummy1149a
# Deleting folder: /Backend_files/Status/dummy1149a
# Deleting folder: dummyc079f
# Deleting folder: /Backend_files/Status/dummyc079f
# Deleting folder: dummy7566f
# Deleting folder: /Backend_files/Status/dummy7566f
# Deleting folder: dummy71da9
# Deleting folder: /Backend_files/Status/dummy71da9
# Deleting folder: dummy07593
# Deleting folder: /Backend_files/Status/dummy07593
