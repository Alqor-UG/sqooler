# %% [markdown]
# # Load simple json

# %%
import json
from pprint import pprint

# %%
fname  = 'job-20211221_122019-multiqudit-fnj-4ed32.json'

with open(fname) as file:
    data = json.load(file)
    pprint(data)
# Out:
# {'experiment_0': {'instructions': [['load', [0], [10.0]],
#                                    ['load', [1], [1.0]],
#                                    ['rlx', [0], [1.5707963267948966]],
#                                    ['barrier', [0, 1], []],
#                                    ['rlz2', [0], [0.0]],
#                                    ['rlz', [1], [0.0]],
#                                    ['rlxly', [0, 1], [0.0]],
#                                    ['barrier', [0, 1], []],
#                                    ['measure', [0], []],
#                                    ['measure', [1], []]],
#                   'num_wires': 2,
#                   'shots': 150,
#                   'wire_order': 'sequential'},
#  'experiment_1': {'instructions': [['load', [0], [10.0]],
#                                    ['load', [1], [1.0]],
#                                    ['rlx', [0], [1.5707963267948966]],
#                                    ['barrier', [0, 1], []],
# ...
